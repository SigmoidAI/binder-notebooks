# %% [markdown]
# # Programming Assignment: Data Splitting Foundations
#
# This notebook groups the core evaluation workflows into one place. You will build a stratified train/validation/test split, verify class balance, run K-fold cross-validation, analyze fold variance, and compare standard KFold with StratifiedKFold on imbalanced data.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to submit your solutions or when explicitly mentioned you can interact with it.
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. Do not add or change code outside these comments.
# * You can add extra cells to experiment, but the grader will only evaluate the graded functions.
# * Avoid using global variables unless a cell explicitly tells you to do so.
# * Save the notebook before submitting it.
# ---

# %% [markdown]
# ## Table of Contents
# - [Imports](#imports)
# - [1 - Build a stratified train/validation/test split](#1)
#     - **[Exercise 1 - create_stratified_splits](#ex-1)**
#     - **[Exercise 2 - summarize_class_proportions](#ex-2)**
# - [2 - Run K-fold cross-validation](#2)
#     - **[Exercise 3 - run_kfold_cv](#ex-3)**
#     - **[Exercise 4 - analyze_fold_variance](#ex-4)**
# - [3 - Compare KFold and StratifiedKFold](#3)
#     - **[Exercise 5 - compare_kfold_strategies](#ex-5)**
#     - **[Exercise 6 - inspect_fold_class_balance](#ex-6)**

# %% [markdown]
# <a name='imports'></a>
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import unittests

from sklearn.datasets import load_breast_cancer, make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold, StratifiedKFold, cross_val_score, train_test_split

# %% [markdown]
# <a name='1'></a>
# ## 1 - Build a stratified train/validation/test split

# %%
X_split, y_split = make_classification(
    n_samples=500,
    n_features=8,
    n_informative=5,
    n_redundant=1,
    weights=[0.8, 0.2],
    random_state=42,
)
X_split = pd.DataFrame(X_split, columns=[f"feature_{i}" for i in range(X_split.shape[1])])
y_split = pd.Series(y_split, name="target")
print(X_split.shape, y_split.mean())

# %% [markdown]
# <a name='ex-1'></a>
# ### Exercise 1 - `create_stratified_splits`
#
# Create a three-way split with stratification. First split off the test set, then split the remaining pool into training and validation sets. Return a dictionary containing all six outputs.

# %%
# GRADED FUNCTION: create_stratified_splits
def create_stratified_splits(X, y, test_size=0.2, val_size=0.25, random_state=42):
    """
    Create train, validation, and test splits while preserving class balance.
    """
    ### START CODE HERE ### (approximately 8 lines)
    X_train_full = None
    X_test = None
    y_train_full = None
    y_test = None

    X_train = None
    X_val = None
    y_train = None
    y_val = None
    ### END CODE HERE ###

    return {
        'X_train': X_train,
        'X_val': X_val,
        'X_test': X_test,
        'y_train': y_train,
        'y_val': y_val,
        'y_test': y_test,
    }

# %%
splits = create_stratified_splits(X_split, y_split)
unittests.exercise_1(create_stratified_splits)

# %% [markdown]
# <a name='ex-2'></a>
# ### Exercise 2 - `summarize_class_proportions`
#
# Build a small DataFrame with class proportions for the training, validation, and test sets. Then use it to verify that the split stayed representative.

# %%
# GRADED FUNCTION: summarize_class_proportions
def summarize_class_proportions(y_train, y_val, y_test):
    """
    Summarize class ratios for train, validation, and test labels.
    """
    ### START CODE HERE ### (approximately 6 lines)
    proportion_df = None
    ### END CODE HERE ###
    return proportion_df

# %%
proportion_df = summarize_class_proportions(
    splits['y_train'], splits['y_val'], splits['y_test']
)
proportion_df

# %%
proportion_df.T.plot(kind='bar', figsize=(8, 4))
plt.ylabel('Proportion')
plt.title('Class Proportions Across Splits')
plt.show()

unittests.exercise_2(summarize_class_proportions)

# %% [markdown]
# <a name='2'></a>
# ## 2 - Run K-fold cross-validation

# %%
X_cv, y_cv = load_breast_cancer(return_X_y=True, as_frame=True)
cv_model = LogisticRegression(max_iter=2000, solver='liblinear')
print(X_cv.shape, y_cv.mean())

# %% [markdown]
# <a name='ex-3'></a>
# ### Exercise 3 - `run_kfold_cv`
#
# Use `KFold` and `cross_val_score` to compute fold-by-fold scores, then return the raw scores and their mean and standard deviation.

# %%
# GRADED FUNCTION: run_kfold_cv
def run_kfold_cv(model, X, y, n_splits=5, shuffle=True, random_state=42, scoring='accuracy'):
    """
    Evaluate a model with K-fold cross-validation.
    """
    ### START CODE HERE ### (approximately 5 lines)
    fold_scores = None
    mean_score = None
    std_score = None
    ### END CODE HERE ###

    return {
        'fold_scores': fold_scores,
        'mean_score': mean_score,
        'std_score': std_score,
    }

# %%
cv_results = run_kfold_cv(cv_model, X_cv, y_cv)
cv_results

# %% [markdown]
# <a name='ex-4'></a>
# ### Exercise 4 - `analyze_fold_variance`
#
# Summarize the fold scores with descriptive statistics so you can reason about stability, not just the average score.

# %%
# GRADED FUNCTION: analyze_fold_variance
def analyze_fold_variance(fold_scores):
    """
    Compute descriptive statistics for an array of fold scores.
    """
    ### START CODE HERE ### (approximately 6 lines)
    summary = None
    ### END CODE HERE ###
    return summary

# %%
variance_summary = analyze_fold_variance(cv_results['fold_scores'])
variance_summary

# %%
plt.plot(range(1, len(cv_results['fold_scores']) + 1), cv_results['fold_scores'], marker='o')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.title('Fold-by-Fold CV Accuracy')
plt.show()

unittests.exercise_3(run_kfold_cv)
unittests.exercise_4(analyze_fold_variance)

# %% [markdown]
# <a name='3'></a>
# ## 3 - Compare KFold and StratifiedKFold

# %%
X_imb, y_imb = make_classification(
    n_samples=600,
    n_features=10,
    n_informative=6,
    n_redundant=1,
    weights=[0.92, 0.08],
    random_state=42,
)
X_imb = pd.DataFrame(X_imb)
y_imb = pd.Series(y_imb)
imb_model = LogisticRegression(max_iter=2000, solver='liblinear')
print(y_imb.mean())

# %% [markdown]
# <a name='ex-5'></a>
# ### Exercise 5 - `compare_kfold_strategies`
#
# Evaluate the same classifier with standard `KFold` and `StratifiedKFold`. Return fold scores and mean scores for both strategies.

# %%
# GRADED FUNCTION: compare_kfold_strategies
def compare_kfold_strategies(model, X, y, n_splits=5, random_state=42):
    """
    Compare standard KFold with StratifiedKFold on an imbalanced dataset.
    """
    ### START CODE HERE ### (approximately 8 lines)
    results = None
    ### END CODE HERE ###
    return results

# %%
strategy_results = compare_kfold_strategies(imb_model, X_imb, y_imb)
strategy_results

# %% [markdown]
# <a name='ex-6'></a>
# ### Exercise 6 - `inspect_fold_class_balance`
#
# Measure the positive-class rate in each validation fold for both splitters. This shows why stratification reduces instability on imbalanced classification tasks.

# %%
# GRADED FUNCTION: inspect_fold_class_balance
def inspect_fold_class_balance(y, n_splits=5, random_state=42):
    """
    Compute the validation-fold positive rate for KFold and StratifiedKFold.
    """
    ### START CODE HERE ### (approximately 12 lines)
    balance_df = None
    ### END CODE HERE ###
    return balance_df

# %%
balance_df = inspect_fold_class_balance(y_imb)
balance_df

# %%
balance_df.plot(kind='bar', figsize=(8, 4))
plt.ylabel('Positive Class Rate')
plt.title('Fold Class Balance: KFold vs StratifiedKFold')
plt.show()

unittests.exercise_5(compare_kfold_strategies)
unittests.exercise_6(inspect_fold_class_balance)
